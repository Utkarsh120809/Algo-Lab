# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import matplotlib.pyplot as plt
import random

def selection_sort(numbers):
    n = len(numbers)
    for i in range(n):
        min_index = i
        for j in range(i + 1, n):
            if numbers[j] < numbers[min_index]:
                min_index = j

        numbers[i], numbers[min_index] = numbers[min_index], numbers[i]
    return numbers


n = int(input("Enter number of elements: "))
numbers = []

for i in range(n):
    element = int(input(f"Enter element {i+1}: "))
    numbers.append(element)

start_time = time.time()
sorted_list = selection_sort(numbers.copy())
end_time = time.time()

print("Sorted List:", sorted_list)
print("Running Time:", end_time - start_time, "seconds")


input_sizes = [100, 200, 300, 400, 500]
times = []

for size in input_sizes:
    test_list = random.sample(range(size * 10), size)
    start = time.time()
    selection_sort(test_list)
    end = time.time()
    times.append(end - start)

plt.plot(input_sizes, times, marker='o')
plt.xlabel("Number of Elements (n)")
plt.ylabel("Time Taken (seconds)")
plt.title("Selection Sort Time Complexity")
plt.grid(True)
plt.show()
# Out:
# Enter number of elements: 5
# Enter element 1: 1
# Enter element 2: 2
# Enter element 3: 3
# Enter element 4: 4
# Enter element 5: 5
# Sorted List: [1, 2, 3, 4, 5]
# Running Time: 9.083747863769531e-05 seconds

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt


def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2

        left = arr[:mid]
        right = arr[mid:]

        merge_sort(left)
        merge_sort(right)

        i = j = k = 0


        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                arr[k] = left[i]
                i += 1
            else:
                arr[k] = right[j]
                j += 1
            k += 1


        while i < len(left):
            arr[k] = left[i]
            i += 1
            k += 1

        while j < len(right):
            arr[k] = right[j]
            j += 1
            k += 1



n = int(input("Enter number of elements: "))
arr = []

for i in range(n):
    element = int(input(f"Enter element {i+1}: "))
    arr.append(element)


start_time = time.time()
merge_sort(arr)
end_time = time.time()

print("Sorted List:", arr)
print("Running Time:", end_time - start_time, "seconds")



input_sizes = [100, 200, 400, 800, 1600]
times = []

for size in input_sizes:
    test_array = random.sample(range(size * 10), size)
    start = time.time()
    merge_sort(test_array)
    end = time.time()
    times.append(end - start)


plt.plot(input_sizes, times, marker='o', color='green')
plt.xlabel("Number of Elements (n)")
plt.ylabel("Time Taken (seconds)")
plt.title("Merge Sort: Time Complexity Analysis")
plt.grid(True)
plt.show()
# Out:
# Enter number of elements: 8
# Enter element 1: 6
# Enter element 2: 24
# Enter element 3: 2
# Enter element 4: 78
# Enter element 5: 45
# Enter element 6: 56
# Enter element 7: 12
# Enter element 8: 34
# Sorted List: [2, 6, 12, 24, 34, 45, 56, 78]
# Running Time: 0.00010895729064941406 seconds

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.
def partition(arr, low, high):
    pivot = arr[high]
    i = low - 1

    for j in range(low, high):
        if arr[j] < pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]

    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return i + 1


def quicksort(arr, low, high):
    if low < high:
        pi = partition(arr, low, high)
        quicksort(arr, low, pi - 1)
        quicksort(arr, pi + 1, high)
import random
import time

def measure_time(n):
    arr = [random.randint(1, 100000) for _ in range(n)]
    start_time = time.time()
    quicksort(arr, 0, n - 1)
    end_time = time.time()
    return end_time - start_time


n_values = [100, 500, 1000, 2000, 5000, 10000]
time_taken = []

for n in n_values:
    t = measure_time(n)
    time_taken.append(t)
    print(f"n = {n}, Time Taken = {t:.6f} seconds")
import matplotlib.pyplot as plt

plt.plot(n_values, time_taken, marker='o', linestyle='-', color='b')
plt.xlabel('Number of Elements (n)')
plt.ylabel('Time Taken (seconds)')
plt.title('Quick Sort: Time Taken vs n')
plt.grid(True)
plt.show()
# Out:
# n = 100, Time Taken = 0.000077 seconds
# n = 500, Time Taken = 0.000690 seconds
# n = 1000, Time Taken = 0.001317 seconds
# n = 2000, Time Taken = 0.002571 seconds
# n = 5000, Time Taken = 0.008216 seconds
# n = 10000, Time Taken = 0.021201 seconds

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[len(n_list) -1]
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]


def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and key < arr[j]:
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key


def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        L = arr[:mid]
        R = arr[mid:]

        merge_sort(L)
        merge_sort(R)

        i = j = k = 0
        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1

        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1

        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1


def partition(arr, low, high):
    pivot = arr[high]
    i = low - 1
    for j in range(low, high):
        if arr[j] < pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]
    arr[i+1], arr[high] = arr[high], arr[i+1]
    return i + 1


def quick_sort(arr, low, high):
    if low < high:
        pi = partition(arr, low, high)
        quick_sort(arr, low, pi - 1)
        quick_sort(arr, pi + 1, high)
import random
import time

n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[-1]

bubble_time = []
insertion_time = []
merge_time = []
quick_time = []

for n in n_list:
    data = [random.randint(1, n) for _ in range(n)]


    if n <= 5000:
        arr = data.copy()
        start = time.time()
        bubble_sort(arr)
        bubble_time.append(time.time() - start)
    else:
        bubble_time.append(None)


    if n <= 10000:
        arr = data.copy()
        start = time.time()
        insertion_sort(arr)
        insertion_time.append(time.time() - start)
    else:
        insertion_time.append(None)


    arr = data.copy()
    start = time.time()
    merge_sort(arr)
    merge_time.append(time.time() - start)


    arr = data.copy()
    start = time.time()
    quick_sort(arr, 0, n - 1)
    quick_time.append(time.time() - start)

    print(f"n={n} completed")

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(n_list, merge_time, label="Merge Sort", marker='o')
plt.plot(n_list, quick_time, label="Quick Sort", marker='o')

plt.plot(n_list, bubble_time, label="Bubble Sort", marker='o', linestyle='dashed')
plt.plot(n_list, insertion_time, label="Insertion Sort", marker='o', linestyle='dashed')

plt.xlabel("Number of Elements (n)")
plt.ylabel("Time Taken (seconds)")
plt.title("Comparison of Sorting Algorithms")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# n=1000 completed
# n=2000 completed
# n=5000 completed
# n=10000 completed
# n=20000 completed
# n=50000 completed
# n=100000 completed
# n=200000 completed

# %%
# Creating a random value (uniform)
from datetime import datetime
import random

ms = datetime.now().microsecond / 1000
random.seed(ms)

numbers = []
for i in range(n_max):
    numbers.append(int(random.random() * 1000))

    from datetime import datetime
import random
import time
import matplotlib.pyplot as plt
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]


def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key


def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        L = arr[:mid]
        R = arr[mid:]

        merge_sort(L)
        merge_sort(R)

        i = j = k = 0
        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1

        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1

        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1


def partition(arr, low, high):
    pivot = arr[high]
    i = low - 1
    for j in range(low, high):
        if arr[j] < pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]
    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return i + 1


def quick_sort(arr, low, high):
    if low < high:
        pi = partition(arr, low, high)
        quick_sort(arr, low, pi - 1)
        quick_sort(arr, pi + 1, high)

bubble_time = []
insertion_time = []
merge_time = []
quick_time = []

for n in n_list:
    data = numbers[:n]

    if n <= 5000:
        arr = data.copy()
        start = time.time()
        bubble_sort(arr)
        bubble_time.append(time.time() - start)
    else:
        bubble_time.append(None)

    if n <= 10000:
        arr = data.copy()
        start = time.time()
        insertion_sort(arr)
        insertion_time.append(time.time() - start)
    else:
        insertion_time.append(None)

    arr = data.copy()
    start = time.time()
    merge_sort(arr)
    merge_time.append(time.time() - start)

    arr = data.copy()
    start = time.time()
    quick_sort(arr, 0, n - 1)
    quick_time.append(time.time() - start)

    print(f"n = {n} done")
plt.figure(figsize=(10, 6))

plt.plot(n_list, merge_time, marker='o', label='Merge Sort')
plt.plot(n_list, quick_time, marker='o', label='Quick Sort')
plt.plot(n_list, bubble_time, marker='o', linestyle='dashed', label='Bubble Sort')
plt.plot(n_list, insertion_time, marker='o', linestyle='dashed', label='Insertion Sort')

plt.xlabel("Number of Elements (n)")
plt.ylabel("Time Taken (seconds)")
plt.title("Sorting Algorithm Comparison")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# n = 1000 done
# n = 2000 done
# n = 5000 done
# n = 10000 done
# n = 20000 done
# n = 50000 done
# n = 100000 done
# n = 200000 done

# %%
from datetime import datetime
import random
a_time = []
b_time = []
c_time = []

for l in n_list:
    a = copy.deepcopy(numbers[0:l])
    b = copy.deepcopy(numbers[0:l])
    c = copy.deepcopy(numbers[0:l])

    start_time = timeit.default_timer()
    quick_sort(a)
    a_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    merge_sort(b)
    b_time.append((timeit.default_timer() - start_time) * 1000)

    start_time = timeit.default_timer()
    selection.sort()
    c_time.append((timeit.default_timer() - start_time) * 1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4150014294.py in <cell line: 0>()
#       6
#       7 for l in n_list:
# ----> 8     a = copy.deepcopy(numbers[0:l])
#       9     b = copy.deepcopy(numbers[0:l])
#      10     c = copy.deepcopy(numbers[0:l])
#
# NameError: name 'copy' is not defined

# %%
# Plotting results
plt.figure(figsize=(10, 5))
plt.plot(a_time, linewidth = 1, marker="o")
plt.plot(b_time, linewidth = 1, marker="o")
plt.plot(c_time, linewidth = 1, marker="o")
plt.xticks(np.arange(len(n_list)), n_list)
plt.title("Compare Sorting Algorithms", fontsize = 14)
plt.ylabel('Time (ms)')
plt.xlabel('n')
plt.legend(("Quicksort", "Mergesort", "Selection sort"), loc = "best")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-716276353.py in <cell line: 0>()
#       1 # Plotting results
# ----> 2 plt.figure(figsize=(10, 5))
#       3 plt.plot(a_time, linewidth = 1, marker="o")
#       4 plt.plot(b_time, linewidth = 1, marker="o")
#       5 plt.plot(c_time, linewidth = 1, marker="o")
#
# NameError: name 'plt' is not defined
